# %% [markdown]
# ## Intro to Python

# %%
 #lets start with hello world

# %%
#print - inbuilt function
#python is case sensitive

print("Hello World")
# Out:
# Hello World

# %%
print("Hello")
# Out:
# Hello

# %%
print(123)
# Out:
# 123

# %%
print( 123+123)
# Out:
# 246

# %%
print("123")
# Out:
# 123

# %%
print("123"+123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fd3063178245> in <cell line: 1>()
# ----> 1 print("123"+123)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("I dont like to get up in the morning")
# Out:
# I dont like to get up in the morning

# %%
print("12233")
# Out:
# 12233

# %%
print(1996)
# Out:
# 1996

# %%
print(3.14)
# Out:
# 3.14

# %%
print(10>5)
# Out:
# True

# %%
print(4>5)
# Out:
# False

# %%
#complex no
print(3+5j)
# Out:
# (3+5j)

# %%
type("hello")
# Out:
# str

# %%
print(type(45))
print(type(45.0))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(type('True'))
# Out:
# <class 'str'>

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
x= 5000
y = 2000

# %%
print(x,y)
# Out:
# 5000 2000

# %%
a ="i am"
b = "not sleepy"

# %%
print(a)
print(b)
# Out:
# i am
# not sleepy

# %%
print(a,b)
# Out:
# i am not sleepy

# %%
x1 =100
print(x1)
# Out:
# 100

# %%
_1x = 100
print(_1x)
# Out:
# 100

# %%
x_y =100
print(x_y)
# Out:
# 100

# %%
print("value is" , x_y)
# Out:
# value is 100

# %%
x =10
y = x
print(y)
# Out:
# 10

# %%
x+y =100

# %%
x = 100
x =200
print(x)
# Out:
# 200

# %%
name = input()
print("Hey Good Morning", name)
# Out:
# x
# Hey Good Morning x

# %%
name = input()
print( name, "Hey Good Morning")
# Out:
# PP
# PP Hey Good Morning

# %%
x = 3
y = 'hello'

# %%
num = y
num
# Out:
# 'hello'

# %%
y = 5
print(num, y)
# Out:
# hello 5

# %%
x =float(input("Enter the first value: "))
y =float(input("Enter the second value: "))
print("Total sum is " ,x+y)
# Out:
# Enter the first value: 10
# Enter the second value: 6
# Total sum is  16.0
