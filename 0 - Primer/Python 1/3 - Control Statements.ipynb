# %%
marks = 40

# %%
if marks >=70:
  print("Congrats, you passed!")
  print("Give the party")
print("Good luck")
# Out:
# Good luck

# %%
if 56 > 50:
  print("1")
  print("2")
print("3")
# Out:
# 1
# 2
# 3

# %%
if 5 > 50:
  print("1")
  print("2")
print("3")
# Out:
# 3

# %%
if 5 > 50:
  print("2")

# %%
## password # if else!
password = "kuchbhi"
enter_password =input("Please enter your password:")

if enter_password == password:
  print("Login Successful")
  print("Welcome to Scaler")
else:
  print("Wrong Password, Try again!")
# Out:
# Please enter your password:kuchbhi
# Login Successful
# Welcome to Scaler

# %%
a =1.5
result = a**5

if result > 25:
  print("Thats Huge!")
else :
  print("Pretty Small!")


print("Thanks for coding")
# Out:
# Pretty Small!
# Thanks for coding

# %% [markdown]
# 0 -24 hours ;
# 0-5 - night
# 5-12- morning
# 12-17 afternnon
# 17-24 evening

# %%
time = int(input())

if time >0 and time <=5:
  print("Good night")
else :
  if time >5 and time <=12:
    print("Good morning")
  else :
    if time >12 and time <=17:
      print("Good afternoon")
    else:
      print("Good Evening")
# Out:
# 18
# Good Evening

# %%
x = 5
if x > 10:
    print("Hello")
else:
    print("World")
# Out:
# World

# %%
bool()

#value =0 then false , value <> True
# value ="str" True, value ="" then False

# %%
x = 100
if x:
    print("True")
else:
    print("False")
# Out:
# True

# %%
time = int(input())

if time >0 and time <=5:
  print("Good night")
else :
  if time >5 and time <=12:
    print("Good morning")
  else :
    if time >12 and time <=17:
      print("Good afternoon")
    else:
      print("Good Evening")

# %%
time = int(input())

if time >0 and time <=5:
  print("Good night")

elif time >5 and time <=12:
  print("Good morning")

elif time >12 and time <=17:
  print("Good afternoon")

else:
  print("Good Evening")
# Out:
# 23
# Good Evening

# %%
x = 2
if x > 2:
    if x < 10:
        print("x is between 2 and 10")
    else:
        print("x is greater than or equal to 10")
else:
    print("x is less than or equal to 2")
# Out:
# x is less than or equal to 2

# %%
2>2
# Out:
# False

# %%
age = 15
if age < 18:
    print("You are not eligible to vote")
elif age >= 18 and age < 21:
    print("You can vote but can't drink")
else:
    print("You can vote and drink")
# Out:
# You are not eligible to vote

# %% [markdown]
# **ATM Dispatch**
# Only Rs. 500 and Rs. 200 notes are available.
# Take an amount as input from user
# if amount is dischargeable, print("Discharging cash")
# else, print("Denomination not available")

# %%
1100, 1700,200,800

# %%
amt =int(input("Enter amt : "))

if amt <=500 and (amt%500)%200 == 0:
  print("discharge cash")
elif amt >500 and ((amt%500)%200)%100 == 0:
  print("discharge cash")
else:
  print("Denomination not available")
# Out:
# Enter amt : 6125
# Denomination not available

# %%
(300%500)%200
# Out:
# 100

# %%
300%500
# Out:
# 300

# %%
300%200
# Out:
# 100
