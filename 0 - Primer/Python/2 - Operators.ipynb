# %%
x= 5
y = 2

# %%
type(x)
# Out:
# int

# %%
print(x+y)
# Out:
# 7

# %%
z = x+y

# %%
print(x)
print(z)
# Out:
# 5
# 7

# %%
10 *2
# Out:
# 20

# %%
3+3.0
# Out:
# 6.0

# %%
3+3
# Out:
# 6

# %%
3+4.0
# Out:
# 7.0

# %%
4.0+4.0
# Out:
# 8.0

# %%
10-5
# Out:
# 5

# %%
10-5.4
# Out:
# 4.6

# %%
10*10
# Out:
# 100

# %%
2.0*10.123
# Out:
# 20.246

# %%
10*2.0
# Out:
# 20.0

# %%
10/5
# Out:
# 2.0

# %%
22/7
# Out:
# 3.142857142857143

# %%
22.0/3
# Out:
# 7.333333333333333

# %%
21.0/3
# Out:
# 7.0

# %%
10/2.5
# Out:
# 4.0

# %%
10 ** 2
# Out:
# 100

# %%
5 ** -1
# Out:
# 0.2

# %%
4 ** 0.5
# Out:
# 2.0

# %%
5 ** 2
# Out:
# 25

# %%
5 ** 0.5
# Out:
# 2.23606797749979

# %%
9 ** 0.5
# Out:
# 3.0

# %%
5.0 ** 2
# Out:
# 25.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10/2
# Out:
# 5.0

# %%
10//2
# Out:
# 5

# %%
22//7
# Out:
# 3

# %%
22.0//7
# Out:
# 3.0

# %%
/, //

# %%
#reminder

10%3
# Out:
# 1

# %%
15%4
# Out:
# 3

# %%
10%-3
# Out:
# -2

# %%
-5%2
# Out:
# 1

# %%
-7%4

# %%
-10.0%3
# Out:
# 2.0

# %%
10-6+1
# Out:
# 5

# %%
10-4*2
# Out:
# 2

# %%
10-4*2+5-6/2

# %%
x = 11
y = 2
z = 4
res = (x + y - z) ** (x % z)
print(res)

# %%
9**3
# Out:
# 729

# %%
11+2-4
# Out:
# 9

# %%
11%4
# Out:
# 3

# %%
bool(5)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
bool(-0.5)
# Out:
# True

# %%
bool('false')
# Out:
# True

# %%
x = int('4')

# %%
type(x)
# Out:
# int

# %%
int(False)
# Out:
# 0

# %%
int(5.9)
# Out:
# 5

# %%
int("Vishnu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-c518ff8365e6> in <cell line: 1>()
# ----> 1 int("Vishnu")
#
# ValueError: invalid literal for int() with base 10: 'Vishnu'

# %%
int(bool('Sayyed'))
# Out:
# 1

# %%
rajat_mark = 85
saurabh_mark = 80

# %%
rajat_mark > saurabh_mark
# Out:
# True

# %%
rajat_mark == saurabh_mark
# Out:
# False

# %%
rajat_mark != saurabh_mark
# Out:
# True

# %%
85 != 85.0
# Out:
# False

# %%
int("1.0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-305a000f9be2> in <cell line: 1>()
# ----> 1 int("1.0")
#
# ValueError: invalid literal for int() with base 10: '1.0'

# %%
85<= 80
# Out:
# False

# %%
25.0> 24.999999999999999999999
# Out:
# False

# %%
int("10")
# Out:
# 10

# %%
float("10.2")
# Out:
# 10.2

# %%
# Question - What will be the output?

a = 5
a += 2
print(a)
a -= 2
print(a)
a *= 2
print(a)
a /= 4
print(a)
# Out:
# 7
# 5
# 10
# 2.5

# %%
a = 5
a *= -4
print(a)
# Out:
# -20

# %%
a = 5
a /= 4
print(a)
# Out:
# 1.25

# %%
a = 5
a = -4
print(a)
# Out:
# -4

# %%
a = 9

# %%
a> 15 or a < 100
# Out:
# True

# %%
print (not a>15)
# Out:
# True

# %%
11 * 2 - 10/5
# Out:
# 20.0

# %%
print( not True)
# Out:
# False
