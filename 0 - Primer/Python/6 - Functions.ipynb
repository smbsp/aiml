# %%
for i in range(3):
  for j in range(3):
    print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
for i in range(3):
  for j in range(3):
    print('*', end =' ')
  print()
# Out:
# * * *
# * * *
# * * *

# %%
for i in range(3):
  for j in range(i,3): # i ==0, 0,1,2, i == 1, 1,2, i ==2 range(2,3) -- 2
    print('*', end =' ')
  print()
# Out:
# * * *
# * *
# *

# %%
for i in range(3):
  for j in range(3-i-1):
    print(" ", end =" ")
  for k in range( 2*i +1):
    print("*", end =" ")
  print()
# Out:
#     *
#   * * *
# * * * * *

# %%
a = 16
b = 24
x = min(a,b)

for i in range(x,0, -1):
  if a%i ==0 and b%i ==0:
    print(i)
    break
# Out:
# 8

# %%
# Out:
# 16

# %%
def guest_checklist():
  print("Dust the room")
  print("Serve Tea")

# %%
guest_checklist()
# Out:
# Dust the room
# Serve Tea

# %%
def make_tea():
  print("Hey there, I am making the tea")

# %%
make_tea()
# Out:
# Hey there, I am making the tea

# %%
for i in range(5):
  make_tea()
# Out:
# Hey there, I am making the tea
# Hey there, I am making the tea
# Hey there, I am making the tea
# Hey there, I am making the tea
# Hey there, I am making the tea

# %%
for i in range(5):
  print("Hey there, I am making the tea")
# Out:
# Hey there, I am making the tea
# Hey there, I am making the tea
# Hey there, I am making the tea
# Hey there, I am making the tea
# Hey there, I am making the tea

# %%
## square

def sqr(n):
  print(n**2)

# %%
sqr(5)
# Out:
# 25

# %%
print("hello")
# Out:
# hello

# %%
min(5,3)
# Out:
# 3

# %%
def sqr_root(n):
  print(n**0.5)

# %%
sqr_root(9)
# Out:
# 3.0

# %%
## area of rectangle  l,b

def area_rect(l,b):
  print(l*b)

# %%
def greet(name):
  print("Hello, sab maaza ma," ,name)

# %%
greet("rochit")
# Out:
# Hello, sab maaza ma, rochit

# %%
def func(n):

# %%
def func(n):
  for i in range(n):
    print("hello")

# %%
func(3)
# Out:
# hello
# hello
# hello

# %%
for i in range(3.0):
  print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-7c36094dad21> in <cell line: 1>()
# ----> 1 for i in range(3.0):
#       2   print(i)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
## return vs print


def add1(a,b):
  print(a+b)

# %%
add1(6,5)
# Out:
# 11

# %%
def add2(a,b):
  return a+b

# %%
add2(6,5)
# Out:
# 11

# %%
ax = add1(6,5)
# Out:
# 11

# %%
print(ax)
# Out:
# None

# %%
axy = add2(5,6)

# %%
axy
# Out:
# 11

# %%
def very_random():
  print("hello before return")
  return 1
  print("hello after return")

# %%
def do_something(n):
    total = 0
    i = 1
    while i <= n:
        total += i
        i += 1
    return total

print(do_something(5))
# Out:
# 15

# %%
very_random()
# Out:
# hello before return
# 1

# %%
def gcd(a,b):
  x = min(a,b)
  for i in range(x,0, -1):
    if a%i ==0 and b%i ==0:
      print(i)
      break

# %%
gcd(5,15)
# Out:
# 5

# %%
area_rect(5,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-235db1154452> in <cell line: 1>()
# ----> 1 area_rect(5)
#
# TypeError: area_rect() missing 1 required positional argument: 'b'

# %%
def area_rect(b=5 , l=5):
  print(l*b)

# %%
area_rect()
# Out:
# 25

# %%
def simple_int(p,t,r=12):
  return (p*r*t)/100

# %%
simple_int(10000,1,4)
# Out:
# 400.0

# %%
def xyz(a, b, c= None):
  print(a,b,c)

# %%
xyz("100","yyy",4)
# Out:
# 100 yyy 4

# %%
##global variables

def random():
  ba = 50
  print("its random", ba)

# %%
ba = 10
def random():
  ba = 50
  print("its random inside", ba)
random()


print("its random outside" ,ba)
# Out:
# its random inside 50
# its random outside 10

# %%
ba = 10
def random():
  ba = 50
  print("its random inside", ba)

def random1():
  print("random 2 ", ba)

print(ba)
random()
random1()
# Out:
# 10
# its random inside 50
# random 2  10

# %%
a = 10
def randomz():
  global a
  a =20
  print(a)

# %%
randomz()
# Out:
# 20

# %%
print(a)
# Out:
# 20

# %%
def multiply(num1=3, num2):
    return num1 * num2

print(multiply(2, 4))
