# %%
runs = [62, 85, 74, 10, 12, 101, 122, 99, 81, 55]

# %%
runs[0:5]
# Out:
# [62, 85, 74, 10, 12]

# %%
#last 5 matches
runs[-5: ]
# Out:
# [101, 122, 99, 81, 55]

# %%
runs[:5]
# Out:
# [62, 85, 74, 10, 12]

# %%
runs[:]
# Out:
# [62, 85, 74, 10, 12, 101, 122, 99, 81, 55]

# %%
runs[3:]
# Out:
# [10, 12, 101, 122, 99, 81, 55]

# %%
#create a new list of runs made in last 5 matches

new_runs = []

for i in range(1,6):
  new_runs.append(runs[-i])

new_runs
# Out:
# [55, 81, 99, 122, 101]

# %%
last = runs[-1:-6:-1]

# %%
runs[-1:-6:-1]
# Out:
# [55, 81, 99, 122, 101]

# %%
x =[9,4,6]

# %%
x[::-1]
# Out:
# [6, 4, 9]

# %%
for i in range(5,0,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
print(runs[5:])
print(runs[:5])
# Out:
# [101, 122, 99, 81, 55]
# [62, 85, 74, 10, 12]

# %%
runs[::-1]
# Out:
# [55, 81, 99, 122, 101, 12, 10, 74, 85, 62]

# %%
runs[::2]
# Out:
# [62, 74, 12, 122, 81]

# %%
runs
# Out:
# [62, 85, 74, 10, 12, 101, 122, 99, 81, 55]

# %%
## create a new list of runs made in odd matches (even index number)

odd_matches_o =[]

for i in range(0,len(runs)):
  if i%2 != 0:
    odd_matches_o.append(runs[i])

odd_matches_o
# Out:
# [85, 10, 101, 99, 55]

# %%
jump_odd =[]
for i in range(0, len(runs), 2):
  jump_odd.append(runs[i])

jump_odd
# Out:
# [62, 74, 12, 122, 81]

# %%
runs[::2] #even
# Out:
# [62, 74, 12, 122, 81]

# %%
runs[1::2] #odd
# Out:
# [85, 10, 101, 99, 55]

# %%
runs[5:0:-1]
# Out:
# [101, 12, 10, 74, 85]

# %%
runs
# Out:
# [62, 85, 74, 10, 12, 101, 122, 99, 81, 55]

# %%
runs[-2:-5:-1]
# Out:
# [81, 99, 122]

# %%
runs[-2::-1]
# Out:
# [81, 99, 122, 101, 12, 10, 74, 85, 62]

# %%
a = [10, 20, 30, 440, 50, 60, 70, 80, 90, 100]

# %%
a[3:5]
# Out:
# [440, 50]

# %%
a[:]
# Out:
# [10, 20, 30, 440, 50, 60, 70, 80, 90, 100]

# %%
a[-2:-5:-1]
# Out:
# [90, 80, 70]

# %%
a[-2:-7]
# Out:
# []

# %%
a[-8:5:-1]
# Out:
# []

# %%
# [1, 2, 3, 4, 5] ⇒ [5, 1, 2, 3, 4]

a = [1, 2, 3, 4, 5]

# %%
x = [a[-1]]
x
# Out:
# [5]

# %%
a[0:len(a)-1]
# Out:
# [1, 2, 3, 4]

# %%
[a[-1]]+a[0:len(a)-1]
# Out:
# [5, 1, 2, 3, 4]

# %%
x= ["a", "e", "f", "i", "b"]

# %%
#reverse, reversed

x.reverse()
x
# Out:
# ['b', 'i', 'f', 'e', 'a']

# %%
print(x)
# Out:
# ['b', 'i', 'f', 'e', 'a']

# %%
y =["a", "e", "f", "i", "b"]

# %%
list(reversed(y))
# Out:
# ['b', 'i', 'f', 'e', 'a']

# %%
y
# Out:
# ['a', 'e', 'f', 'i', 'b']

# %%
y[::-1]
# Out:
# ['b', 'i', 'f', 'e', 'a']

# %%
a = [[1,2,3],
     [4,5,6],
     [7,8,9]]

# %%
print(a)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
a[1][2]
# Out:
# 6

# %%
a =[[1,2,[6,9,[12,15]]]]

# %%
a[0][2][2][0]
# Out:
# 12

# %%
a =  [[10,20,30],[40,50,60],[70,80,90]]

# %%
for i in a:
  for j in i:
    print(j, end =" ")
  print()
# Out:
# 10 20 30
# 40 50 60
# 70 80 90

# %%
random = [[1, 2, 3], ["a", "b", "c", "d", "e"], [4.5, 6.7]]

for i in random:
  for j in i:
    print(j, end =" ")
  print()
# Out:
# 1 2 3
# a b c d e
# 4.5 6.7

# %%
a =  [[10,20,30],[40,50,60],[70,80,90]]
rows = len(a)
rows
# Out:
# 3

# %%
col = len(a[0])

# %%
for i in range(rows):
  for j in range(col):
    print(a[i][j], end =" ")
  print()
# Out:
# 10 20 30
# 40 50 60
# 70 80 90

# %%
a[1][0]
# Out:
# 40

# %%
# user to give me the values and we want to create a list

## enter the no of elements in the list

num_elements = int(input("Enter the no of elements"))
# Out:
# Enter the no of elements2

# %%
my_list =[]

for i in range(num_elements):
  elements = input()
  my_list.append(elements)

print(my_list)
# Out:
# 2
# 4
# ['2', '4']

# %%
#Take a 3X3 matrix as an input from the user.

#Given this matrix -

#Calculate the sum of all the elements in the matrix.
#Calculate the sum of elements in each row.

# %%
a =[]
for i in range(3):
  inner_list =[]
  for i in range(3):
    inner_list.append(int(input()))
  a.append(inner_list)

print(a)
# Out:
# 66
# 77
# 88
# 85
# 99
# 44
# 33
# 66
# 92
# [[66, 77, 88], [85, 99, 44], [33, 66, 92]]

# %%
a
# Out:
# [[66, 77, 88], [85, 99, 44], [33, 66, 92]]

# %%
sum_all =0
for i in a:
  for j in i:
    sum_all = sum_all+j
print(sum_all)
# Out:
# 650
