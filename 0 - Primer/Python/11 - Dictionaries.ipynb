# %%
s ={1,2,3}

# %%
type(s)
# Out:
# set

# %%
s1 ={'a':1, 'b':2, 'c':3} #k,v k:v

# %%
cust_id =[1,2,3]
age =[21,22,23]

# %%
df ={'cust_id':[1,2,3],
     'age':[21,22,23]}

# %%
df['age'][2]
# Out:
# 23

# %%
a = {
    "random": "something which is not well defined",
    "bizzare": "something which is unusual"
}

# %%
type(a)
# Out:
# dict

# %%
a['random']
# Out:
# 'something which is not well defined'

# %%
city_wise_data = {
    "Delhi": 450,
    "Mumbai": 400,
    "Bengaluru": 325
}

# %%
city_wise_data_tup = [("Delhi", 450), ("Mumbai", 400), ("Bengaluru", 325)]

# %%
city_wise_data_tup[0][1]
# Out:
# 450

# %%
city_wise_data['Delhi']
# Out:
# 450

# %%
city_wise_data['Delhi'] = 500

# %%
city_wise_data
# Out:
# {'Delhi': 500, 'Mumbai': 400, 'Bengaluru': 325}

# %%
df ={'cust_id':(1,2,3),
     'age':[21,22,23],
     'income' :{100,100,200}}

# %%
df['age'][0] =25

# %%
city_wise_data['New Delhi'] =480

# %%
city_wise_data
# Out:
# {'Delhi': 500, 'Mumbai': 400, 'Bengaluru': 325, 'New Delhi': 480}

# %%
df
# Out:
# {'cust_id': (1, 2, 3), 'age': [21, 22, 23], 'income': {100, 200}}

# %%
a =[5,6,7,8]

# %%
a.append(100)

# %%
a
# Out:
# [5, 6, 7, 8, 100, 100]

# %%
df ={'cust_id':[1,2,3],
     'age':[21,22,23]}

# %%
df['location'] =['Blr', 'Pune', 'Mumbai']

# %%
df['location'] =['Blr', 'Pune', 'Mum']

# %%
df
# Out:
# {'cust_id': [1, 2, 3], 'age': [21, 22, 23], 'location': ['Blr', 'Pune', 'Mum']}

# %%
df.update({'status': [1,0,0], 'name': ['Ram', 'shyam','laxam'], 'age':[22,23,24]})

# %%
df
# Out:
# {'cust_id': [1, 2, 3],
#  'age': [22, 23, 24],
#  'location': ['Blr', 'Pune', 'Mum'],
#  'status': [1, 0, 0],
#  'name': ['Ram', 'shyam', 'laxam']}

# %%
c ={'a':1, 'b':2, 'a':100}

# %%
c
# Out:
# {'a': 100, 'b': 2}

# %%
df
# Out:
# {'cust_id': [1, 2, 3],
#  'age': [22, 23, 24],
#  'location': ['Blr', 'Pune', 'Mum'],
#  'status': [1, 0, 0],
#  'name': ['Ram', 'shyam', 'laxam']}

# %%
df['asasasas']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-447f8b76e842> in <cell line: 1>()
# ----> 1 df['asasasas']
#
# KeyError: 'asasasas'

# %%
##get

# %%
df.get('age')
# Out:
# [22, 23, 24]

# %%
df.get('asasasas')

# %%
a =[5,6,7,8]

# %%
a.pop()
# Out:
# 8

# %%
a1 ={5,9,7,7,6,2}

# %%
a1.pop()
# Out:
# 2

# %%
df.pop('status')
# Out:
# [1, 0, 0]

# %%
del df['age']

# %%
df.clear()
df
# Out:
# {}

# %%
df = {'cust_id': [1, 2, 3],
 'age': [22, 23, 24],
 'location': ['Blr', 'Pune', 'Mum'],
 'status': [1, 0, 0],
 'name': ['Ram', 'shyam', 'laxam']}

# %%
df['name'].pop()
# Out:
# 'laxam'

# %%
df
# Out:
# {'cust_id': [1, 2, 3],
#  'age': [22, 23, 24],
#  'location': ['Blr', 'Pune', 'Mum'],
#  'status': [1, 0, 0],
#  'name': ['Ram', 'shyam']}

# %%
for i in df:
  print(i)
# Out:
# cust_id
# age
# location
# status
# name

# %%
for i in df:
  print(i,":", df[i])
# Out:
# cust_id : [1, 2, 3]
# age : [22, 23, 24]
# location : ['Blr', 'Pune', 'Mum']
# status : [1, 0, 0]
# name : ['Ram', 'shyam']

# %%
for i in df:
  print(f"Column Name is {i}, values are {df[i]}")
# Out:
# Column Name is cust_id, values are [1, 2, 3]
# Column Name is age, values are [22, 23, 24]
# Column Name is location, values are ['Blr', 'Pune', 'Mum']
# Column Name is status, values are [1, 0, 0]
# Column Name is name, values are ['Ram', 'shyam']

# %%
df['cust_id']= tuple(df['cust_id'])

# %%
df.keys()
# Out:
# dict_keys(['cust_id', 'age', 'location', 'status', 'name'])

# %%
df.values()
# Out:
# dict_values([(1, 2, 3), [22, 23, 24], ['Blr', 'Pune', 'Mum'], [1, 0, 0], ['Ram', 'shyam']])

# %%
df.items()
# Out:
# dict_items([('cust_id', (1, 2, 3)), ('age', [22, 23, 24]), ('location', ['Blr', 'Pune', 'Mum']), ('status', [1, 0, 0]), ('name', ['Ram', 'shyam'])])

# %%
for key, value in df.items():
  print(key, value)
# Out:
# cust_id (1, 2, 3)
# age [22, 23, 24]
# location ['Blr', 'Pune', 'Mum']
# status [1, 0, 0]
# name ['Ram', 'shyam']

# %%
for i,j in df.items():
  print(i,j)
# Out:
# cust_id (1, 2, 3)
# age [22, 23, 24]
# location ['Blr', 'Pune', 'Mum']
# status [1, 0, 0]
# name ['Ram', 'shyam']

# %%
for i,j in df.items():
  print(i,j)
# Out:
# cust_id (1, 2, 3)
# age [22, 23, 24]
# location ['Blr', 'Pune', 'Mum']
# status [1, 0, 0]
# name ['Ram', 'shyam']

# %%
for i in df.values():
  print(i)
# Out:
# (1, 2, 3)
# [22, 23, 24]
# ['Blr', 'Pune', 'Mum']
# [1, 0, 0]
# ['Ram', 'shyam']

# %%
for i in df:
  print(i)
# Out:
# cust_id
# age
# location
# status
# name

# %%
for i in df:
  print(i, df[i])
# Out:
# cust_id (1, 2, 3)
# age [22, 23, 24]
# location ['Blr', 'Pune', 'Mum']
# status [1, 0, 0]
# name ['Ram', 'shyam']

# %%
"age" in df.keys()
# Out:
# True

# %%
"asasaead" in df.keys()
# Out:
# False

# %%
e ={'key1':'val1', 'key2':['val2','val3']}
print(['val2', 'val3'] in e.values())
# Out:
# True

# %%
d = {'key1': 'val1', 'key2': 'val2', 'key3': 'val3'}

print('val1' in d.values())
# Out:
# True

# %%
d = {'key1': 'val1', 'key2': 'val2', 'key3': 'val3'}

print('val1' in d.values())
# Out:
# True

# %%
random ={
    "key1": [5,6,7],
    "key2": (4,5,6),
    "set1":{4,8,9},
    "new loop":{"new_key":1},
    "a": 1,
    "b": 1.0,
    "c": "abcc",
    "d": True
}

# %%
new_random = {
    1 : [1,2,3],
    1.0:(6,7,9),
    "a": (75,44,66),
    True: [77,88]
}

# %%
will_work ={
    {'k':1} :"a"
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-26e211f36ed4> in <cell line: 2>()
# ----> 1 will_work ={
#       2     {'k':1} :"a"
#       3 }
#
# TypeError: unhashable type: 'dict'

# %%
a ={'#':3,2024:4,2022:5}

# %%
a['#']
# Out:
# 3

# %%
my_dict = {'banana': 3, 'apple': 2, 'orange': 5, 'grape': 1}

# %%
my_dict
# Out:
# {'banana': 3, 'apple': 2, 'orange': 5, 'grape': 1}

# %%
dict(sorted(my_dict.items()))
# Out:
# {'apple': 2, 'banana': 3, 'grape': 1, 'orange': 5}

# %%
dict(sorted(my_dict.items(),key = lambda x: x[1], reverse=True ))
# Out:
# {'orange': 5, 'banana': 3, 'apple': 2, 'grape': 1}

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
t = (5,8,1,2)
sorted(t)
# Out:
# [1, 2, 5, 8]

# %%
for i in my_dict:
  print(my_dict[i])
# Out:
# 3
# 2
# 5
# 1

# %%
[('banana', 3), ('apple', 2), ('orange', 5), ('grape', 1)]

# %%
random ="zzzzztttteeee"
set(r)
# Out:
# {'r', 's', 't'}

# %%
random.count('t')
# Out:
# 4

# %%
result ={}
for i in set(random):
  result[i] =random.count(i)
print(dict(sorted(result.items())))
# Out:
# {'e': 4, 't': 4, 'z': 5}

# %%
result
# Out:
# {'t': 4, 'r': 2, 's': 4}

# %%
set(random)
# Out:
# {'r', 's', 't'}

# %%
random.count('r')
# Out:
# 2
