# %%
A = [[1, 2, 3],
     [4, 5, 6],
     [7, 8, 9]]

B = [[9, 8, 7],
     [6, 5, 4],
     [3, 2, 1]]

# %%
rows = len(A)
cols = len(A[0])

C =[]
for i in range(rows):
  C.append([])
  for j in range(cols):
    C[i].append(A[i][j]+B[i][j])
C
# Out:
# [[10, 10, 10], [10, 10, 10], [10, 10, 10]]

# %%
a = " axxxxyyy"

'
'''

# %%
def sq(x):
  ''' this fuction takes the square of the number '''
  return x*x

# %%
sq(5)
# Out:
# 25

# %%
help(sq)
# Out:
# Help on function sq in module __main__:
#
# sq(x)
#     this fuction takes the square of the number

# %%
x ="%^&**()"
type(x)
# Out:
# str

# %%
ord("a")
# Out:
# 97

# %%
ord("'")
# Out:
# 39

# %%
chr(1234)
# Out:
# 'Ӓ'

# %%
'a' == 'A'
# Out:
# False

# %%
'a' >'A'
# Out:
# True

# %%
'a' >'Arttttttttttttt'
# Out:
# True

# %%
"pp"*2
# Out:
# 'pppp'

# %%
"PP"+"pp"
# Out:
# 'PPpp'

# %%
'a'*2*3
# Out:
# 'aaaaaa'

# %%
'aA'>'aB'
# Out:
# False

# %%
ord('A')
# Out:
# 65

# %%
ord('B')
# Out:
# 66

# %%
65>66
# Out:
# False

# %%
'a'*'b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-3a7abb6af42d> in <cell line: 1>()
# ----> 1 'a'*'b'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
l = 5
b = 10
a = l*b

# %%
print("lenght is" ,l, 'breath is', b, "Total area is", a)
# Out:
# lenght is 5 breath is 10 Total area is 50

# %%
print("lengh is {}, breath is {}, area is {} ".format(l,b,a))
# Out:
# lengh is 5, breath is 10, area is 50

# %%
print(f"lengh is {l}, breath is {b}, area is {a} ")
# Out:
# lengh is 5, breath is 10, area is 50

# %%
message = "Hello World!"
i = 0
while i < len(message):
  if i % 2 == 0:
    print(message[i], end = "")
  i += 1
# Out:
# HloWrd

# %%
s ='h '

# %%
s[1]
# Out:
# ' '

# %%
message = "Hello World!"

# %%
message[0:4:2]
# Out:
# 'Hl'

# %%
"4 5 6 7".split()
# Out:
# ['4', '5', '6', '7']

# %%
"a b c d".split()
# Out:
# ['a', 'b', 'c', 'd']

# %%
"this_is_a_new_title".split("_")
# Out:
# ['this', 'is', 'a', 'new', 'title']

# %%
str1 = 'abcd,bbb,eeee'

# %%
str1.split(",")
# Out:
# ['abcd bbb eeee']

# %%
11111.split()
# Out:
#   File "<ipython-input-64-ff89e73abb6a>", line 1
#     11111.split()
#          ^
# SyntaxError: invalid decimal literal

# %%
x = "1 1 1 1 1 1"

# %%
y = x.split()

# %%
y
# Out:
# ['1', '1', '1', '1', '1', '1']

# %%
"-".join(y)
# Out:
# '1-1-1-1-1-1'

# %%
z = ['this', 'is', 'a', 'new', 'title']

# %%
" ".join(z)
# Out:
# 'this is a new title'

# %%
str(45)
# Out:
# '45'

# %%
'45'
# Out:
# '45'

# %%
"this is totally random".find("randoms")
# Out:
# -1

# %%
random1 = "This is a random string that I have created i know this totaly random"
random1.replace("random", "Super Random")
# Out:
# 'This is a Super Random string that I have created i know this totaly Super Random'

# %%
random1
# Out:
# 'This is a random string that I have created i know this totaly random'

# %%
float('10,000')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-41a7a65a8104> in <cell line: 1>()
# ----> 1 float('10,000')
#
# ValueError: could not convert string to float: '10,000'

# %%
x = '10,00,000'

# %%
float(x.replace(",",""))
# Out:
# 1000000.0

# %%
random1.count('random')
# Out:
# 2

# %%
"abc".isdigit()
# Out:
# False

# %%
"abc1".isalpha()
# Out:
# False

# %%
"abc-".isalnum()
# Out:
# False

# %%
"A".isupper()
# Out:
# True

# %%
"A".islower()
# Out:
# False

# %%
"a".upper()
# Out:
# 'A'

# %%
n ="naman"
n[::-1]
# Out:
# 'naman'

# %%
def check_palindrome(a):
  a =a.lower()
  return "is palindrome" if a == a[::-1] else "not palindrome"

# %%
check_palindrome("Arora")
# Out:
# 'is palindrome'

# %%
i = "Jump"

# %%
i[::-1]
# Out:
# 'pmuJ'

# %%
message = "Hello World!"
print(message.replace("o", "e"))
# Out:
# Helle Werld!

# %%
message
# Out:
# 'Hello World!'

# %%
a = "aaaa"
id(a)
# Out:
# 133598354448048

# %%
a = "bbbbb"
id(a)
# Out:
# 133598354451120

# %%
a
# Out:
# 'bbbbb'

# %%
b =[1,2,3]
id(b)
# Out:
# 133598356354048

# %%
b.append(200)
b
# Out:
# [1, 2, 3, 200]

# %%
id(b)
# Out:
# 133598356354048

# %%
x = "Amit"
id(x)
# Out:
# 133598356398128

# %%
x = "hari"
id(x)
# Out:
# 133598356404656

# %%
x1 =['Amit']
id(x1)
# Out:
# 133598357237952

# %%
x1[0] ='Hari'
x1
# Out:
# ['Hari']

# %%
id(x1)
# Out:
# 133598357237952

# %%
x ="rajat"
x.append("sharma")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-157-4efb2fe107c6> in <cell line: 2>()
#       1 x ="rajat"
# ----> 2 x.append("sharma")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
p = "Hello"
p[0] ="L"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-13057452294d> in <cell line: 2>()
#       1 p = "Hello"
# ----> 2 p[0] ="L"
#
# TypeError: 'str' object does not support item assignment

# %%
a = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
ans =[]
for i in range(3):
  curr_sum = 0
  for j in range(3):
    curr_sum = curr_sum+ a[j][i]
  ans.append(curr_sum)

ans
# Out:
# [12, 15, 18]
